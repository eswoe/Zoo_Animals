# %%
import pandas as pd

# %%
#RSQ:
#What taxonomic class of animal survives longest in captivity? Which survives the shortest amount of time?

# %%
animals_df = pd.read_csv('Downloads/animals_dataset.csv', delimiter=',')

# %%
pd.options.display.max_rows = 100

# %%
animals_df = animals_df.set_index('Species Common Name')

# %%
animals_df
# Out:
#                                     Scientific Name TaxonClass  \
# Species Common Name
# Addax                           Addax nasomaculatus   Mammalia
# Agouti, Brazilian               Dasyprocta leporina   Mammalia
# Alligator, Chinese               Alligator sinensis   Reptilia
# Anoa, Lowland                Bubalus depressicornis   Mammalia
# Anteater, Giant             Myrmecophaga tridactyla   Mammalia
# ...                                             ...        ...
# Woodhoopoe, Green             Phoeniculus purpureus       Aves
# Wood-partridge, Crested            Rollulus rouloul       Aves
# Zebra, Grevy's                         Equus grevyi   Mammalia
# Zebra, Hartmann's Mountain   Equus zebra hartmannae   Mammalia
# Zebra, Plains                         Equus quagga    Mammalia
#
#                             Overall Sample Size   Overall MLE  \
# Species Common Name
# Addax                                     1215.0         13.4
# Agouti, Brazilian                          456.0          8.1
# Alligator, Chinese                         351.0         30.9
# Anoa, Lowland                              256.0         17.7
# Anteater, Giant                            177.0         19.7
# ...                                          ...          ...
# Woodhoopoe, Green                          284.0          5.4
# Wood-partridge, Crested                   1319.0          4.8
# Zebra, Grevy's                             797.0         14.1
# Zebra, Hartmann's Mountain                 585.0         13.9
# Zebra, Plains                             1635.0         15.6
#
#                             Overall CI - lower  Overall CI - upper  \
# Species Common Name
# Addax                                     12.4                14.5
# Agouti, Brazilian                          7.2                 9.3
# Alligator, Chinese                        25.9                34.3
# Anoa, Lowland                             15.3                21.2
# Anteater, Giant                           17.1                21.5
# ...                                        ...                 ...
# Woodhoopoe, Green                          4.5                 6.3
# Wood-partridge, Crested                    4.6                 5.1
# Zebra, Grevy's                            12.9                15.3
# Zebra, Hartmann's Mountain                12.3                15.3
# Zebra, Plains                             14.4                16.5
#
#                             Male Sample Size  Male MLE  Male CI - lower  \
# Species Common Name
# Addax                                  558.0      12.3             10.5
# Agouti, Brazilian                      216.0       8.8              6.9
# Alligator, Chinese                     151.0      25.9             23.9
# Anoa, Lowland                          113.0      16.3             14.7
# Anteater, Giant                         86.0      19.4             17.1
# ...                                      ...       ...              ...
# Woodhoopoe, Green                      136.0       6.0              4.7
# Wood-partridge, Crested                645.0       5.0              4.6
# Zebra, Grevy's                         341.0      11.2              8.8
# Zebra, Hartmann's Mountain             283.0      12.3             10.8
# Zebra, Plains                          638.0      14.0             11.6
#
#                             Male CI - upper  Female Sample Size   Female MLE  \
# Species Common Name
# Addax                                  14.7                656.0        14.4
# Agouti, Brazilian                      10.3                220.0         7.8
# Alligator, Chinese                     52.1                176.0        32.8
# Anoa, Lowland                          21.3                139.0        18.8
# Anteater, Giant                        21.5                 90.0        19.7
# ...                                     ...                  ...         ...
# Woodhoopoe, Green                       7.0                130.0         4.3
# Wood-partridge, Crested                 5.3                633.0         4.7
# Zebra, Grevy's                         13.2                455.0        16.5
# Zebra, Hartmann's Mountain             13.9                301.0        15.4
# Zebra, Plains                          15.9                991.0        16.0
#
#                             Female CI - lower Female CI - upper  \
# Species Common Name
# Addax                                    13.0              15.1
# Agouti, Brazilian                         6.8               8.6
# Alligator, Chinese                       25.9                46
# Anoa, Lowland                            15.2              21.5
# Anteater, Giant                          16.2                22
# ...                                       ...               ...
# Woodhoopoe, Green                         3.2                 6
# Wood-partridge, Crested                   4.3                 5
# Zebra, Grevy's                           14.4                18
# Zebra, Hartmann's Mountain               13.2                17
# Zebra, Plains                            14.9                17
#
#                            Male Data Deficient Female Data Deficient
# Species Common Name
# Addax                                      NaN                   NaN
# Agouti, Brazilian                          NaN                   NaN
# Alligator, Chinese                         yes                   yes
# Anoa, Lowland                              yes                   yes
# Anteater, Giant                            yes                   yes
# ...                                        ...                   ...
# Woodhoopoe, Green                          NaN                   NaN
# Wood-partridge, Crested                    NaN                   NaN
# Zebra, Grevy's                             NaN                   NaN
# Zebra, Hartmann's Mountain                 NaN                   NaN
# Zebra, Plains                              NaN                   NaN
#
# [330 rows x 16 columns]

# %%
animals_df = animals_df.rename(columns={'Overall MLE': 'Overall Median Life Expectancy'})
animals_df = animals_df.rename(columns={'Male MLE': 'Male Median Life Expectancy'})
animals_df = animals_df.rename(columns={'Female MLE': 'Female Median Life Expectancy'})
animals_df = animals_df.drop(columns='')
animals_df
# Out:
#                                     Scientific Name TaxonClass  \
# Species Common Name
# Addax                           Addax nasomaculatus   Mammalia
# Agouti, Brazilian               Dasyprocta leporina   Mammalia
# Alligator, Chinese               Alligator sinensis   Reptilia
# Anoa, Lowland                Bubalus depressicornis   Mammalia
# Anteater, Giant             Myrmecophaga tridactyla   Mammalia
# ...                                             ...        ...
# Woodhoopoe, Green             Phoeniculus purpureus       Aves
# Wood-partridge, Crested            Rollulus rouloul       Aves
# Zebra, Grevy's                         Equus grevyi   Mammalia
# Zebra, Hartmann's Mountain   Equus zebra hartmannae   Mammalia
# Zebra, Plains                         Equus quagga    Mammalia
#
#                             Overall Sample Size   \
# Species Common Name
# Addax                                     1215.0
# Agouti, Brazilian                          456.0
# Alligator, Chinese                         351.0
# Anoa, Lowland                              256.0
# Anteater, Giant                            177.0
# ...                                          ...
# Woodhoopoe, Green                          284.0
# Wood-partridge, Crested                   1319.0
# Zebra, Grevy's                             797.0
# Zebra, Hartmann's Mountain                 585.0
# Zebra, Plains                             1635.0
#
#                             Overall Median Life Expectancy  \
# Species Common Name
# Addax                                                 13.4
# Agouti, Brazilian                                      8.1
# Alligator, Chinese                                    30.9
# Anoa, Lowland                                         17.7
# Anteater, Giant                                       19.7
# ...                                                    ...
# Woodhoopoe, Green                                      5.4
# Wood-partridge, Crested                                4.8
# Zebra, Grevy's                                        14.1
# Zebra, Hartmann's Mountain                            13.9
# Zebra, Plains                                         15.6
#
#                             Overall CI - lower  Overall CI - upper  \
# Species Common Name
# Addax                                     12.4                14.5
# Agouti, Brazilian                          7.2                 9.3
# Alligator, Chinese                        25.9                34.3
# Anoa, Lowland                             15.3                21.2
# Anteater, Giant                           17.1                21.5
# ...                                        ...                 ...
# Woodhoopoe, Green                          4.5                 6.3
# Wood-partridge, Crested                    4.6                 5.1
# Zebra, Grevy's                            12.9                15.3
# Zebra, Hartmann's Mountain                12.3                15.3
# Zebra, Plains                             14.4                16.5
#
#                             Male Sample Size  Male Median Life Expectancy  \
# Species Common Name
# Addax                                  558.0                         12.3
# Agouti, Brazilian                      216.0                          8.8
# Alligator, Chinese                     151.0                         25.9
# Anoa, Lowland                          113.0                         16.3
# Anteater, Giant                         86.0                         19.4
# ...                                      ...                          ...
# Woodhoopoe, Green                      136.0                          6.0
# Wood-partridge, Crested                645.0                          5.0
# Zebra, Grevy's                         341.0                         11.2
# Zebra, Hartmann's Mountain             283.0                         12.3
# Zebra, Plains                          638.0                         14.0
#
#                             Male CI - lower  Male CI - upper  \
# Species Common Name
# Addax                                  10.5             14.7
# Agouti, Brazilian                       6.9             10.3
# Alligator, Chinese                     23.9             52.1
# Anoa, Lowland                          14.7             21.3
# Anteater, Giant                        17.1             21.5
# ...                                     ...              ...
# Woodhoopoe, Green                       4.7              7.0
# Wood-partridge, Crested                 4.6              5.3
# Zebra, Grevy's                          8.8             13.2
# Zebra, Hartmann's Mountain             10.8             13.9
# Zebra, Plains                          11.6             15.9
#
#                             Female Sample Size   \
# Species Common Name
# Addax                                     656.0
# Agouti, Brazilian                         220.0
# Alligator, Chinese                        176.0
# Anoa, Lowland                             139.0
# Anteater, Giant                            90.0
# ...                                         ...
# Woodhoopoe, Green                         130.0
# Wood-partridge, Crested                   633.0
# Zebra, Grevy's                            455.0
# Zebra, Hartmann's Mountain                301.0
# Zebra, Plains                             991.0
#
#                             Female Median Life Expectancy  Female CI - lower  \
# Species Common Name
# Addax                                                14.4               13.0
# Agouti, Brazilian                                     7.8                6.8
# Alligator, Chinese                                   32.8               25.9
# Anoa, Lowland                                        18.8               15.2
# Anteater, Giant                                      19.7               16.2
# ...                                                   ...                ...
# Woodhoopoe, Green                                     4.3                3.2
# Wood-partridge, Crested                               4.7                4.3
# Zebra, Grevy's                                       16.5               14.4
# Zebra, Hartmann's Mountain                           15.4               13.2
# Zebra, Plains                                        16.0               14.9
#
#                            Female CI - upper Male Data Deficient  \
# Species Common Name
# Addax                                   15.1                 NaN
# Agouti, Brazilian                        8.6                 NaN
# Alligator, Chinese                        46                 yes
# Anoa, Lowland                           21.5                 yes
# Anteater, Giant                           22                 yes
# ...                                      ...                 ...
# Woodhoopoe, Green                          6                 NaN
# Wood-partridge, Crested                    5                 NaN
# Zebra, Grevy's                            18                 NaN
# Zebra, Hartmann's Mountain                17                 NaN
# Zebra, Plains                             17                 NaN
#
#                            Female Data Deficient
# Species Common Name
# Addax                                        NaN
# Agouti, Brazilian                            NaN
# Alligator, Chinese                           yes
# Anoa, Lowland                                yes
# Anteater, Giant                              yes
# ...                                          ...
# Woodhoopoe, Green                            NaN
# Wood-partridge, Crested                      NaN
# Zebra, Grevy's                               NaN
# Zebra, Hartmann's Mountain                   NaN
# Zebra, Plains                                NaN
#
# [330 rows x 16 columns]

# %%
animals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, Addax to Zebra, Plains
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Scientific Name                 330 non-null    object
#  1   TaxonClass                      330 non-null    object
#  2   Overall Sample Size             328 non-null    float64
#  3   Overall Median Life Expectancy  328 non-null    float64
#  4   Overall CI - lower              328 non-null    float64
#  5   Overall CI - upper              328 non-null    float64
#  6   Male Sample Size                324 non-null    float64
#  7   Male Median Life Expectancy     324 non-null    float64
#  8   Male CI - lower                 324 non-null    float64
#  9   Male CI - upper                 314 non-null    float64
#  10  Female Sample Size              326 non-null    float64
#  11  Female Median Life Expectancy   326 non-null    float64
#  12  Female CI - lower               326 non-null    float64
#  13  Female CI - upper               319 non-null    object
#  14  Male Data Deficient             72 non-null     object
#  15  Female Data Deficient           60 non-null     object
# dtypes: float64(11), object(5)
# memory usage: 43.8+ KB

# %%
animals_df.describe(include='all')
# Out:
#         Scientific Name TaxonClass  Overall Sample Size   \
# count               330        330            328.000000
# unique              329          6                   NaN
# top     Atelopus zeteki   Mammalia                   NaN
# freq                  2        175                   NaN
# mean                NaN        NaN            472.807927
# std                 NaN        NaN            472.047297
# min                 NaN        NaN             50.000000
# 25%                 NaN        NaN            187.000000
# 50%                 NaN        NaN            330.000000
# 75%                 NaN        NaN            545.750000
# max                 NaN        NaN           3406.000000
#
#         Overall Median Life Expectancy  Overall CI - lower  \
# count                       328.000000          328.000000
# unique                             NaN                 NaN
# top                                NaN                 NaN
# freq                               NaN                 NaN
# mean                         13.404878           11.685671
# std                           7.527497            6.736160
# min                           2.400000            2.200000
# 25%                           7.800000            6.600000
# 50%                          12.050000           10.400000
# 75%                          16.625000           14.725000
# max                          47.000000           38.000000
#
#         Overall CI - upper  Male Sample Size  Male Median Life Expectancy  \
# count           328.000000        324.000000                   324.000000
# unique                 NaN               NaN                          NaN
# top                    NaN               NaN                          NaN
# freq                   NaN               NaN                          NaN
# mean             14.976677        210.182099                    13.391049
# std               8.263849        198.729091                     7.463315
# min               2.700000         26.000000                     2.600000
# 25%               9.075000         85.750000                     7.900000
# 50%              13.500000        146.000000                    11.550000
# 75%              18.800000        249.000000                    17.300000
# max              52.900000       1425.000000                    51.300000
#
#         Male CI - lower  Male CI - upper  Female Sample Size   \
# count        324.000000       314.000000           326.000000
# unique              NaN              NaN                  NaN
# top                 NaN              NaN                  NaN
# freq                NaN              NaN                  NaN
# mean          10.924691        15.387898           224.726994
# std            6.364852         8.431720           209.396618
# min            2.300000         3.000000            24.000000
# 25%            6.200000         9.400000            94.000000
# 50%            9.700000        13.400000           156.000000
# 75%           14.100000        19.775000           276.500000
# max           41.300000        54.700000          1335.000000
#
#         Female Median Life Expectancy  Female CI - lower Female CI - upper  \
# count                       326.00000         326.000000               319
# unique                            NaN                NaN               190
# top                               NaN                NaN              18.3
# freq                              NaN                NaN                 5
# mean                         13.45184          11.059509               NaN
# std                           7.83753           6.862371               NaN
# min                           2.40000           2.000000               NaN
# 25%                           7.42500           5.925000               NaN
# 50%                          11.80000           9.600000               NaN
# 75%                          16.57500          13.750000               NaN
# max                          43.30000          40.400000               NaN
#
#        Male Data Deficient Female Data Deficient
# count                   72                    60
# unique                   2                     2
# top                    yes                   yes
# freq                    70                    57
# mean                   NaN                   NaN
# std                    NaN                   NaN
# min                    NaN                   NaN
# 25%                    NaN                   NaN
# 50%                    NaN                   NaN
# 75%                    NaN                   NaN
# max                    NaN                   NaN

# %%
#Insights:
    #There are 6 unique taxonomic classes of animals represesented in the dataset
    #The taxonomic class with the greatest representation is Mammalia with a count of 175 out of 330
    #The average Overall Median Life Expectancy for all animals in captivity is 13.40 years
    #The minimum Overall Median Life Expectancy for all animals in captivity is 2.40 years
    #The maximum Overall Median Life Expectancy for all animals in captivity is 47.00 years
    
    #The average Male Median Life Expectancy for animals in captivity is 13.39 years
    #The average Female Median Life Expectancy for animals in captivity is 13.45 years

# %%
animals_df['TaxonClass'].value_counts()
# Out:
# Mammalia          175
# Aves              125
# Reptilia           21
# Amphibia            6
# Chondrichthyes      2
# Arachnida           1
# Name: TaxonClass, dtype: int64

# %%
animals_df['TaxonClass'].value_counts()[:330].plot(kind='pie', figsize=(10, 10), title='Animals by Taxonomy')
# Out:
# <AxesSubplot:title={'center':'Animals by Taxonomy'}, ylabel='TaxonClass'>

# %%
animals_df['TaxonClass'].value_counts()[:330].plot(kind='bar', figsize=(10, 10), title='Animal Count by Taxonomic Class')
# Out:
# <AxesSubplot:title={'center':'Animal Count by Taxonomic Class'}>

# %%
animals_df['Male Data Deficient'].value_counts()
# Out:
# yes     70
# yes      2
# Name: Male Data Deficient, dtype: int64

# %%
animals_df['Female Data Deficient'].value_counts()
# Out:
# yes     57
# yes      3
# Name: Female Data Deficient, dtype: int64

# %%
#Insights:
    #Of the 330 datasets of animal life expectancy information examined a total of 132 (or 40%) failed at least one 
    #of the five data quality tests

# %%
longestlife = animals_df.nlargest(10, 'Overall Median Life Expectancy')
longestlife
# Out:
#                                         Scientific Name TaxonClass  \
# Species Common Name
# Condor, Andean                           Vultur gryphus       Aves
# Elephant, Asian                         Elephas maximus   Mammalia
# Chimpanzee                              Pan troglodytes   Mammalia
# Elephant, African                    Loxodonta africana   Mammalia
# Bonobo                                     Pan paniscus   Mammalia
# Hippopotamus, River              Hippopotamus amphibius   Mammalia
# Gorilla, Western Lowland        Gorilla gorilla gorilla   Mammalia
# Flamingo, Greater           Phoenicopterus ruber roseus       Aves
# Orangutan, Bornean                       Pongo pygmaeus   Mammalia
# Rhinoceros, Southern White         Cerathotherium simum   Mammalia
#
#                             Overall Sample Size   \
# Species Common Name
# Condor, Andean                             264.0
# Elephant, Asian                            636.0
# Chimpanzee                                 685.0
# Elephant, African                          489.0
# Bonobo                                     297.0
# Hippopotamus, River                        219.0
# Gorilla, Western Lowland                   608.0
# Flamingo, Greater                          799.0
# Orangutan, Bornean                         178.0
# Rhinoceros, Southern White                 618.0
#
#                             Overall Median Life Expectancy  \
# Species Common Name
# Condor, Andean                                        47.0
# Elephant, Asian                                       42.0
# Chimpanzee                                            36.3
# Elephant, African                                     36.3
# Bonobo                                                35.6
# Hippopotamus, River                                   35.5
# Gorilla, Western Lowland                              35.3
# Flamingo, Greater                                     34.9
# Orangutan, Bornean                                    31.5
# Rhinoceros, Southern White                            31.4
#
#                             Overall CI - lower  Overall CI - upper  \
# Species Common Name
# Condor, Andean                            38.0                52.9
# Elephant, Asian                           37.5                45.7
# Chimpanzee                                32.7                39.4
# Elephant, African                         32.2                38.7
# Bonobo                                    31.8                37.8
# Hippopotamus, River                       32.5                39.5
# Gorilla, Western Lowland                  33.3                37.1
# Flamingo, Greater                         33.9                37.1
# Orangutan, Bornean                        27.7                34.6
# Rhinoceros, Southern White                29.1                33.0
#
#                             Male Sample Size  Male Median Life Expectancy  \
# Species Common Name
# Condor, Andean                         132.0                         51.3
# Elephant, Asian                        110.0                         32.0
# Chimpanzee                             299.0                         31.6
# Elephant, African                      108.0                         24.1
# Bonobo                                 134.0                         31.5
# Hippopotamus, River                     93.0                         35.7
# Gorilla, Western Lowland               296.0                         31.7
# Flamingo, Greater                      355.0                         37.0
# Orangutan, Bornean                      83.0                         27.3
# Rhinoceros, Southern White             275.0                         32.0
#
#                             Male CI - lower  Male CI - upper  \
# Species Common Name
# Condor, Andean                         41.3             54.7
# Elephant, Asian                        21.0             40.1
# Chimpanzee                             26.6             35.4
# Elephant, African                      20.0             30.1
# Bonobo                                 25.6             35.7
# Hippopotamus, River                    28.3             41.0
# Gorilla, Western Lowland               30.4             34.6
# Flamingo, Greater                      36.8              NaN
# Orangutan, Bornean                     20.0             31.4
# Rhinoceros, Southern White             27.0             35.4
#
#                             Female Sample Size   \
# Species Common Name
# Condor, Andean                            132.0
# Elephant, Asian                           526.0
# Chimpanzee                                386.0
# Elephant, African                         381.0
# Bonobo                                    163.0
# Hippopotamus, River                       123.0
# Gorilla, Western Lowland                  312.0
# Flamingo, Greater                         409.0
# Orangutan, Bornean                         95.0
# Rhinoceros, Southern White                343.0
#
#                             Female Median Life Expectancy  Female CI - lower  \
# Species Common Name
# Condor, Andean                                       38.8               35.5
# Elephant, Asian                                      43.3               40.4
# Chimpanzee                                           40.0               35.7
# Elephant, African                                    38.0               35.6
# Bonobo                                               43.2               33.4
# Hippopotamus, River                                  35.3               31.1
# Gorilla, Western Lowland                             38.3               35.2
# Flamingo, Greater                                    34.2               30.8
# Orangutan, Bornean                                   38.5               31.0
# Rhinoceros, Southern White                           30.4               26.1
#
#                            Female CI - upper Male Data Deficient  \
# Species Common Name
# Condor, Andean                          52.9                 yes
# Elephant, Asian                         47.1                 NaN
# Chimpanzee                              45.6                 NaN
# Elephant, African                       40.9                 NaN
# Bonobo                                   NaN                 NaN
# Hippopotamus, River                     41.6                 NaN
# Gorilla, Western Lowland                41.3                 NaN
# Flamingo, Greater                       37.1                 yes
# Orangutan, Bornean                        43                 NaN
# Rhinoceros, Southern White                33                 NaN
#
#                            Female Data Deficient
# Species Common Name
# Condor, Andean                               yes
# Elephant, Asian                              NaN
# Chimpanzee                                   NaN
# Elephant, African                            NaN
# Bonobo                                       yes
# Hippopotamus, River                          NaN
# Gorilla, Western Lowland                     NaN
# Flamingo, Greater                            NaN
# Orangutan, Bornean                           yes
# Rhinoceros, Southern White                   NaN

# %%
#Insights:
    #The top 10 animals from the dataset with the longest Overall Median Life Expectancy are part of the Aves
    #and Mammalia taxonomies

# %%
shortestlife = animals_df.nsmallest(10, 'Overall Median Life Expectancy')
shortestlife
# Out:
#                                    Scientific Name TaxonClass  \
# Species Common Name
# Gecko, Mossy Leaf-tailed         Uroplatus sikorae   Reptilia
# Gecko, Satanic Leaf-tailed  Uroplatus phantasticus   Reptilia
# Buttonquail, Madagascar         Turnix nigricollis       Aves
# Pitta, Hooded                        Pitta sordida       Aves
# Frog, Golden Harlequin             Atelopus varius   Amphibia
# Crake, Black                  Zapornia flavirostra       Aves
# Chat, Snowy-Headed Robin     Cossypha niveicapilla       Aves
# Gecko, Giant Leaf-tailed      Uroplatus fimbriatus   Reptilia
# Tanager, Turquoise                Tangara mexicana       Aves
# Cardinal, Red-crested            Paroaria coronata       Aves
#
#                             Overall Sample Size   \
# Species Common Name
# Gecko, Mossy Leaf-tailed                   150.0
# Gecko, Satanic Leaf-tailed                 135.0
# Buttonquail, Madagascar                     78.0
# Pitta, Hooded                              224.0
# Frog, Golden Harlequin                     437.0
# Crake, Black                               370.0
# Chat, Snowy-Headed Robin                   239.0
# Gecko, Giant Leaf-tailed                   306.0
# Tanager, Turquoise                         498.0
# Cardinal, Red-crested                      422.0
#
#                             Overall Median Life Expectancy  \
# Species Common Name
# Gecko, Mossy Leaf-tailed                               2.4
# Gecko, Satanic Leaf-tailed                             2.5
# Buttonquail, Madagascar                                3.2
# Pitta, Hooded                                          3.2
# Frog, Golden Harlequin                                 3.6
# Crake, Black                                           3.7
# Chat, Snowy-Headed Robin                               4.0
# Gecko, Giant Leaf-tailed                               4.0
# Tanager, Turquoise                                     4.0
# Cardinal, Red-crested                                  4.1
#
#                             Overall CI - lower  Overall CI - upper  \
# Species Common Name
# Gecko, Mossy Leaf-tailed                   2.3                 2.7
# Gecko, Satanic Leaf-tailed                 2.2                 3.0
# Buttonquail, Madagascar                    2.9                 4.7
# Pitta, Hooded                              2.6                 3.7
# Frog, Golden Harlequin                     3.3                 4.1
# Crake, Black                               3.4                 4.2
# Chat, Snowy-Headed Robin                   3.3                 5.0
# Gecko, Giant Leaf-tailed                   3.4                 4.5
# Tanager, Turquoise                         3.6                 4.3
# Cardinal, Red-crested                      3.6                 4.8
#
#                             Male Sample Size  Male Median Life Expectancy  \
# Species Common Name
# Gecko, Mossy Leaf-tailed                72.0                          2.6
# Gecko, Satanic Leaf-tailed              65.0                          2.8
# Buttonquail, Madagascar                 35.0                          3.3
# Pitta, Hooded                          109.0                          3.7
# Frog, Golden Harlequin                 123.0                          3.6
# Crake, Black                           128.0                          4.1
# Chat, Snowy-Headed Robin               103.0                          4.8
# Gecko, Giant Leaf-tailed               147.0                          3.5
# Tanager, Turquoise                     235.0                          3.9
# Cardinal, Red-crested                  157.0                          4.2
#
#                             Male CI - lower  Male CI - upper  \
# Species Common Name
# Gecko, Mossy Leaf-tailed                2.3              3.0
# Gecko, Satanic Leaf-tailed              2.3              3.3
# Buttonquail, Madagascar                 2.9              5.2
# Pitta, Hooded                           2.6              4.1
# Frog, Golden Harlequin                  3.3              4.3
# Crake, Black                            3.4              4.5
# Chat, Snowy-Headed Robin                3.4              6.2
# Gecko, Giant Leaf-tailed                3.1              4.5
# Tanager, Turquoise                      3.5              4.4
# Cardinal, Red-crested                   3.5              5.0
#
#                             Female Sample Size   \
# Species Common Name
# Gecko, Mossy Leaf-tailed                   74.0
# Gecko, Satanic Leaf-tailed                 66.0
# Buttonquail, Madagascar                    41.0
# Pitta, Hooded                             110.0
# Frog, Golden Harlequin                     94.0
# Crake, Black                              134.0
# Chat, Snowy-Headed Robin                  110.0
# Gecko, Giant Leaf-tailed                  150.0
# Tanager, Turquoise                        235.0
# Cardinal, Red-crested                     164.0
#
#                             Female Median Life Expectancy  Female CI - lower  \
# Species Common Name
# Gecko, Mossy Leaf-tailed                              2.4                2.0
# Gecko, Satanic Leaf-tailed                            2.4                2.0
# Buttonquail, Madagascar                               3.2                2.7
# Pitta, Hooded                                         3.0                2.4
# Frog, Golden Harlequin                                3.6                3.0
# Crake, Black                                          3.6                3.1
# Chat, Snowy-Headed Robin                              3.8                2.8
# Gecko, Giant Leaf-tailed                              4.2                3.5
# Tanager, Turquoise                                    4.0                3.3
# Cardinal, Red-crested                                 3.9                3.3
#
#                            Female CI - upper Male Data Deficient  \
# Species Common Name
# Gecko, Mossy Leaf-tailed                 2.7                 NaN
# Gecko, Satanic Leaf-tailed                 3                 NaN
# Buttonquail, Madagascar                  4.2                 yes
# Pitta, Hooded                            3.8                 NaN
# Frog, Golden Harlequin                   4.5                 NaN
# Crake, Black                             3.9                 NaN
# Chat, Snowy-Headed Robin                   5                 NaN
# Gecko, Giant Leaf-tailed                 4.9                 NaN
# Tanager, Turquoise                       4.8                 NaN
# Cardinal, Red-crested                    5.2                 NaN
#
#                            Female Data Deficient
# Species Common Name
# Gecko, Mossy Leaf-tailed                     NaN
# Gecko, Satanic Leaf-tailed                   NaN
# Buttonquail, Madagascar                      NaN
# Pitta, Hooded                                NaN
# Frog, Golden Harlequin                       NaN
# Crake, Black                                 NaN
# Chat, Snowy-Headed Robin                     NaN
# Gecko, Giant Leaf-tailed                     NaN
# Tanager, Turquoise                           NaN
# Cardinal, Red-crested                        NaN

# %%
#Insights:
    #The top 10 animals from the dataset with the shortest Overall Median Life Expectancy are part of the Aves,
    #Reptilia, and Amphibia taxonomies

# %%
Reptilia = [animals_df.loc[(animals_df['TaxonClass'] == 'Reptilia', 'Overall Median Life Expectancy')]]

# %%
Reptilia
# Out:
# [Species Common Name
#  Alligator, Chinese                   30.9
#  Boa, Jamaican                        17.4
#  Bushmaster, South American            7.8
#  Dragon, Komodo                       16.6
#  Gecko, Giant Leaf-tailed              4.0
#  Gecko, Henkel's Leaf-tailed           4.5
#  Gecko, Lined Leaf-tailed              4.5
#  Gecko, Mossy Leaf-tailed              2.4
#  Gecko, Satanic Leaf-tailed            2.5
#  Iguana, Fiji Island Banded            9.7
#  Lizard, Chinese Crocodile            12.2
#  Lizard, Rio Fuerte Beaded            24.2
#  Python, Reticulated                  11.1
#  Rattlesnake, Eastern Massasauga       8.7
#  Rattlesnake, Mexican Lance-headed     8.4
#  Snake, Eastern Indigo                11.4
#  Snake, Louisiana Pine                15.6
#  Tortoise, Egyptian                   12.5
#  Turtle, Coahuilan Box                14.6
#  Turtle, Wood                         13.1
#  Viper, Philippine Palm               12.1
#  Name: Overall Median Life Expectancy, dtype: float64]

# %%
Aves = [animals_df.loc[(animals_df['TaxonClass'] == 'Aves', 'Overall Median Life Expectancy')]]

# %%
Aves
# Out:
# [Species Common Name
#  Aracari, Green                 7.9
#  Argus, Great                  10.8
#  Barbet, Red and Yellow         4.6
#  Bird-of-paradise, Raggiana    14.5
#  Bluebird, Fairy                5.0
#                                ...
#  Turaco, Violaceous            14.1
#  Turaco, White-cheeked         10.0
#  Vulture, King                  NaN
#  Woodhoopoe, Green              5.4
#  Wood-partridge, Crested        4.8
#  Name: Overall Median Life Expectancy, Length: 125, dtype: float64]

# %%
Amphibia = [animals_df.loc[(animals_df['TaxonClass'] == 'Amphibia', 'Overall Median Life Expectancy')]]

# %%
Amphibia
# Out:
# [Species Common Name
#  Frog, Dusky Gopher                                    6.6
#  Frog, Golden Harlequin                                3.6
#  Frog, Panamanian Golden (Ahogado)                     7.5
#  Frog, Panamanian Golden (Sora)                        4.6
#  Toad, Houston                                         4.7
#  Toad, Puerto Rican Crested (Northern and Southern)    5.2
#  Name: Overall Median Life Expectancy, dtype: float64]

# %%
Arachnida = [animals_df.loc[(animals_df['TaxonClass'] == 'Arachnida', 'Overall Median Life Expectancy')]]

# %%
Arachnida
# Out:
# [Species Common Name
#  Tarantula, Mexican Red-kneed   NaN
#  Name: Overall Median Life Expectancy, dtype: float64]

# %%
Tarantula = animals_df.loc[animals_df['TaxonClass'] == 'Arachnida']
Tarantula
# Out:
#                                  Scientific Name TaxonClass  \
# Species Common Name
# Tarantula, Mexican Red-kneed  Brachypelma smithi  Arachnida
#
#                               Overall Sample Size   \
# Species Common Name
# Tarantula, Mexican Red-kneed                   NaN
#
#                               Overall Median Life Expectancy  \
# Species Common Name
# Tarantula, Mexican Red-kneed                             NaN
#
#                               Overall CI - lower  Overall CI - upper  \
# Species Common Name
# Tarantula, Mexican Red-kneed                 NaN                 NaN
#
#                               Male Sample Size  Male Median Life Expectancy  \
# Species Common Name
# Tarantula, Mexican Red-kneed               NaN                          NaN
#
#                               Male CI - lower  Male CI - upper  \
# Species Common Name
# Tarantula, Mexican Red-kneed              NaN              NaN
#
#                               Female Sample Size   \
# Species Common Name
# Tarantula, Mexican Red-kneed                 78.0
#
#                               Female Median Life Expectancy  \
# Species Common Name
# Tarantula, Mexican Red-kneed                           17.2
#
#                               Female CI - lower Female CI - upper  \
# Species Common Name
# Tarantula, Mexican Red-kneed               13.8              17.9
#
#                              Male Data Deficient Female Data Deficient
# Species Common Name
# Tarantula, Mexican Red-kneed                 yes                   NaN
